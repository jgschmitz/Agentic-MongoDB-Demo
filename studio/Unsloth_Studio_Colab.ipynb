# %% [markdown]
# <a href="https://colab.research.google.com/github/jgschmitz/Agentic-MongoDB-Demo/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1911, done.
# remote: Counting objects: 100% (1911/1911), done.
# remote: Compressing objects: 100% (1713/1713), done.
# remote: Total 1911 (delta 204), reused 1109 (delta 172), pack-reused 0 (from 0)
# Receiving objects: 100% (1911/1911), 37.93 MiB | 26.90 MiB/s, done.
# Resolving deltas: 100% (204/204), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  upgrading npm...
#   node           v20.19.0 | npm 11.17.0
#                  installing bun...
#                  bun installed (1.3.14)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/14  base packages         deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [====================] 14/14  torch final (cuda)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#   transformers   5.10.2 pre-installed
#   gpu            NVIDIA GPU detected
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b9601-mix-a0e2906 (tag b9601)
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-06-12 14:33:22 [info     ] 🦥 Starting Unsloth Studio...
# 2026-06-12 14:33:22 [info     ]    Loading backend...
# 2026-06-12 14:33:22 [info     ]    Starting server...
# INFO:     Started server process [2547]
# INFO:     Waiting for application startup.
# Hardware detected: CUDA -- Tesla T4
# INFO:     Application startup complete.
# INFO:     Unsloth Studio running on http://34.125.254.83:8888 (To stop: press Ctrl+C -- on macOS, Control+C not Command+C)
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Studio UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-06-12T14:33:34.283203Z", "level": "info", "event": "   Server started on port 8888!"}
# {"timestamp": "2026-06-12T14:33:34.509091Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.81}
# {"timestamp": "2026-06-12T14:33:35.458828Z", "level": "info", "event": "\ud83c\udf10 Unsloth Studio URL: https://8888-gpu-t4-s-kkb-usw4a0-2w37hy8o8cwws-a.us-west4-0.prod.colab.dev"}
# <div style="font-family:system-ui,-apple-system,sans-serif;margin:8px 0;
#             border-radius:12px;overflow:hidden;box-shadow:0 2px 16px rgba(0,0,0,0.18);">
#   <div style="display:flex;align-items:center;gap:10px;padding:10px 16px;background:#000;">
#     <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#          height="26" style="display:block;">
#     <span style="color:#fff;font-weight:700;font-size:15px;letter-spacing:-0.2px;">Unsloth Studio</span>
#     <span style="margin-left:auto;color:#666;font-size:11px;font-family:monospace;">https://8888-gpu-...</span>
#   </div>
#   <iframe
#     id="unsloth-studio-8888"
#     src="https://8888-gpu-t4-s-kkb-usw4a0-2w37hy8o8cwws-a.us-west4-0.prod.colab.dev"
#     style="width:100%;height:82vh;min-height:600px;max-height:1100px;border:none;display:block;box-sizing:border-box;"
#     allow="clipboard-read; clipboard-write"
#   ></iframe>
# </div>
# {"timestamp": "2026-06-12T14:33:35.854123Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 5.44}
# {"timestamp": "2026-06-12T14:33:37.251959Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.88}
# {"timestamp": "2026-06-12T14:33:37.368554Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.81}
# {"timestamp": "2026-06-12T14:33:37.478272Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.88}
# {"timestamp": "2026-06-12T14:33:37.604382Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 2.99}
# {"timestamp": "2026-06-12T14:33:37.713494Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.26}
# {"timestamp": "2026-06-12T14:33:38.142122Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.75}
# WARNING:torchao:Skipping import of cpp extensions due to incompatible torch version 2.10.0+cu128 for torchao version 0.14.0         Please see GitHub issue #2919 for more info
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# {"timestamp": "2026-06-12T14:34:30.283775Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 156.35}
# {"timestamp": "2026-06-12T14:34:30.714546Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 310.52}
# {"timestamp": "2026-06-12T14:34:30.833879Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 4.57}
# {"timestamp": "2026-06-12T14:34:30.849168Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/projects", "status_code": 200, "process_time_ms": 3.57}
# {"timestamp": "2026-06-12T14:34:30.860159Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.19}
# {"timestamp": "2026-06-12T14:34:30.882800Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/active-downloads", "status_code": 200, "process_time_ms": 6.26}
# {"timestamp": "2026-06-12T14:34:30.895996Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/active-downloads", "status_code": 200, "process_time_ms": 7.84}
# {"timestamp": "2026-06-12T14:34:30.900708Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 4.88}
# {"timestamp": "2026-06-12T14:34:30.967888Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.51}
# {"timestamp": "2026-06-12T14:34:31.012482Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 3.01}
# {"timestamp": "2026-06-12T14:34:31.131262Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.81}
# {"timestamp": "2026-06-12T14:34:31.244787Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 4.28}
# {"timestamp": "2026-06-12T14:34:31.355014Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.47}
# {"timestamp": "2026-06-12T14:34:31.364125Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/projects", "status_code": 200, "process_time_ms": 3.55}
# {"timestamp": "2026-06-12T14:34:31.370274Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 3.25}
# {"timestamp": "2026-06-12T14:34:31.460375Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.41}
# {"timestamp": "2026-06-12T14:34:31.479823Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 2.43}
# {"timestamp": "2026-06-12T14:34:31.568750Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.98}
# {"timestamp": "2026-06-12T14:34:31.593754Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/projects", "status_code": 200, "process_time_ms": 3.59}
# {"timestamp": "2026-06-12T14:34:31.606484Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 4.7}
# {"timestamp": "2026-06-12T14:34:31.614586Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-06-12T14:34:31.816580Z", "level": "info", "event": "Top GGUF models: ['unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/gemma-4-26B-A4B-it-GGUF', 'unsloth/Qwen3.6-35B-A3B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/gemma-4-E2B-it-GGUF', 'unsloth/Qwen3.6-27B-GGUF', 'unsloth/gemma-4-E4B-it-GGUF', 'unsloth
z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 1.87}
# {"timestamp": "2026-06-12T14:35:03.762713Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/projects", "status_code": 200, "process_time_ms": 2.28}
# {"timestamp": "2026-06-12T14:35:03.867087Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/projects", "status_code": 200, "process_time_ms": 1.83}
# {"timestamp": "2026-06-12T14:35:04.171251Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/llama/update-status", "status_code": 200, "process_time_ms": 2.4}
# {"timestamp": "2026-06-12T14:35:07.689741Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/projects", "status_code": 200, "process_time_ms": 2.35}
# {"timestamp": "2026-06-12T14:35:07.700332Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.81}
# {"timestamp": "2026-06-12T14:35:07.709041Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-06-12T14:35:07.710243Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-06-12T14:35:07.714530Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 9.74}
# {"timestamp": "2026-06-12T14:35:07.715778Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 9.62}
# {"timestamp": "2026-06-12T14:35:07.732113Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 12.9}
# {"timestamp": "2026-06-12T14:35:07.732906Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 13.53}
# {"timestamp": "2026-06-12T14:35:07.734087Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 14.36}
# {"timestamp": "2026-06-12T14:35:07.737126Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 17.24}
# {"timestamp": "2026-06-12T14:35:07.855319Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 6.62}
# {"timestamp": "2026-06-12T14:35:08.199496Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 3.96}
# {"timestamp": "2026-06-12T14:35:08.205183Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-06-12T14:35:08.218491Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/upload-limit", "status_code": 200, "process_time_ms": 16.97}
# {"timestamp": "2026-06-12T14:35:08.341321Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 8.09}
# {"timestamp": "2026-06-12T14:35:08.369156Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 167.34}
# {"timestamp": "2026-06-12T14:35:14.129081Z", "level": "info", "event": "Getting model config for: ggml-org/models"}
# {"timestamp": "2026-06-12T14:35:14.136477Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-06-12T14:35:14.910638Z", "level": "warning", "event": "Could not determine if ggml-org/models is vision model: Unrecognized model in ggml-org/models. Should have a `model_type` key in its config.json, or contain one of the following strings in its name: aimv2, aimv2_vision_model, albert, align, altclip, apertus, arcee, aria, aria_text, audio-spectrogram-transformer, autoformer, aya_vision, bamba, bark, bart, beit, bert, bert-generation, big_bird, bigbird_pegasus, biogpt, bit, bitnet, blenderbot, blenderbot-small, blip, blip-2, blip_2_qformer, bloom, blt, bridgetower, bros, camembert, canine, chameleon, chinese_clip, chinese_clip_vision_model, clap, clip, clip_text_model, clip_vision_model, clipseg, clvp, code_llama, codegen, cohere, cohere2, cohere2_vision, colpali, colqwen2, conditional_detr, convbert, convnext, convnextv2, cpmant, csm, ctrl, cvt, d_fine, dab-detr, dac, data2vec-audio, data2vec-text, data2vec-vision, dbrx, deberta, deberta-v2, decision_transformer, deepseek_v2, deepseek_v3, deepseek_vl, deepseek_vl_hybrid, deformable_detr, deit, depth_anything, depth_pro, deta, detr, dia, diffllama, dinat, dinov2, dinov2_with_registers, dinov3_convnext, dinov3_vit, distilbert, doge, donut-swin, dots1, dpr, dpt, edgetam, edgetam_video, edgetam_vision_model, efficientformer, efficientloftr, efficientnet, electra, emu3, encodec, encoder-decoder, eomt, ernie, ernie4_5, ernie4_5_moe, ernie_m, esm, evolla, exaone4, falcon, falcon_h1, falcon_mamba, fastspeech2_conformer, fastspeech2_conformer_with_hifigan, flaubert, flava, flex_olmo, florence2, fnet, focalnet, fsmt, funnel, fuyu, gemma, gemma2, gemma3, gemma3_text, gemma3n, gemma3n_audio, gemma3n_text, gemma3n_vision, git, glm, glm4, glm4_moe, glm4v, glm4v_moe, glm4v_moe_text, glm4v_text, glpn, got_ocr2, gpt-sw3, gpt2, gpt_bigcode, gpt_neo, gpt_neox, gpt_neox_japanese, gpt_oss, gptj, gptsan-japanese, granite, granite_speech, granitemoe, granitemoehybrid, granitemoeshared, granitevision, graphormer, grounding-dino, groupvit, helium, hgnet_v2, hiera, hubert, hunyuan_v1_dense, hunyuan_v1_moe, ibert, idefics, idefics2, idefics3, idefics3_vision, ijepa, imagegpt, informer, instructblip, instructblipvideo, internvl, internvl_vision, jamba, janus, jetmoe, jukebox, kosmos-2, kosmos-2.5, kyutai_speech_to_text, layoutlm, layoutlmv2, layoutlmv3, led, levit, lfm2, lfm2_vl, lightglue, lilt, llama, llama4, llama4_text, llava, llava_next, llava_next_video, llava_onevision, longcat_flash, longformer, longt5, luke, lxmert, m2m_100, mamba, mamba2, marian, markuplm, mask2former, maskformer, maskformer-swin, mbart, mctct, mega, megatron-bert, metaclip_2, mgp-str, mimi, minimax, ministral, mistral, mistral3, mixtral, mlcd, mllama, mm-grounding-dino, mobilebert, mobilenet_v1, mobilenet_v2, mobilevit, mobilevitv2, modernbert, modernbert-decoder, moonshine, moshi, mpnet, mpt, mra, mt5, musicgen, musicgen_melody, mvp, nat, nemotron, nezha, nllb-moe, nougat, nystromformer, olmo, olmo2, olmo3, olmoe, omdet-turbo, oneformer, open-llama, openai-gpt, opt, ovis2, owlv2, owlvit, paligemma, parakeet_ctc, parakeet_encoder, patchtsmixer, patchtst, pegasus, pegasus_x, perceiver, perception_encoder, perception_lm, persimmon, phi, phi3, phi4_multimodal, phimoe, pix2struct, pixtral, plbart, poolformer, pop2piano, prompt_depth_anything, prophetnet, pvt, pvt_v2, qdqbert, qwen2, qwen2_5_omni, qwen2_5_vl, qwen2_5_vl_text, qwen2_audio, qwen2_audio_encoder, qwen2_moe, qwen2_vl, qwen2_vl_text, qwen3, qwen3_moe, qwen3_next, qwen3_omni_moe, qwen3_vl, qwen3_vl_moe, qwen3_vl_moe_text, qwen3_vl_text, rag, realm, recurrent_gemma, reformer, regnet, rembert, resnet, retribert, roberta, roberta-prelayernorm, roc_bert, roformer, rt_detr, rt_detr_resnet, rt_detr_v2, rwkv, sam, sam2, sam2_hiera_det_model, sam2_video, sam2_vision_model, sam_hq, sam_hq_vision_model, sam_vision_model, seamless_m4t, seamless_m4t_v2, seed_oss, segformer, seggpt, sew, sew-d, shieldgemma2, siglip, siglip2, siglip2_vision_model, siglip_vision_m ...
# {"timestamp": "2026-06-12T14:35:15.835475Z", "level": "info", "event": "Detected remote GGUF repo 'ggml-org/models', variant=Q8_0, vision=False"}
# {"timestamp": "2026-06-12T14:35:16.007842Z", "level": "info", "event": "Model config result for ggml-org/models: is_vision=False, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-06-12T14:35:16.190640Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/ggml-org/models", "status_code": 200, "process_time_ms": 2063.41}
# {"timestamp": "2026-06-12T14:35:23.628334Z", "level": "info", "event": "Checking format for dataset: unsloth/alpaca-cleaned"}
# {"timestamp": "2026-06-12T14:35:23.739518Z", "level": "info", "event": "Tier 1: loading single file alpaca_data_cleaned.json"}
# README.md: 0.00B [00:00, ?B/s]
# {"timestamp": "2026-06-12T14:35:26.566729Z", "level": "info", "event": "Format check result: requires_mapping=False, format=alpaca, is_image=False"}
# {"timestamp": "2026-06-12T14:35:26.570413Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2945.6}
# {"timestamp": "2026-06-12T14:35:28.222428Z", "level": "info", "event": "Checking format for dataset: unsloth/alpaca-cleaned"}
# {"timestamp": "2026-06-12T14:35:28.307255Z", "level": "info", "event": "Tier 1: loading single file alpaca_data_cleaned.json"}
# {"timestamp": "2026-06-12T14:35:30.222083Z", "level": "info", "event": "Format check result: requires_mapping=False, format=alpaca, is_image=False"}
# {"timestamp": "2026-06-12T14:35:30.227030Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2006.62}
# {"timestamp": "2026-06-12T14:35:30.342788Z", "level": "info", "event": "Starting training job with model: ggml-org/models"}
# {"timestamp": "2026-06-12T14:35:30.352005Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-06-12T14:35:30.353146Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-06-12T14:35:30.706184Z", "level": "info", "event": "Detected remote GGUF repo 'ggml-org/models', variant=Q8_0, vision=False"}
# {"timestamp": "2026-06-12T14:35:31.066788Z", "level": "warning", "event": "Could not load config for 'ggml-org/models': Unrecognized model in ggml-org/models. Should have a `model_type` key in its config.json, or contain one of the following strings in its name: aimv2, aimv2_vision_model, albert, align, altclip, apertus, arcee, aria, aria_text, audio-spectrogram-transformer, autoformer, aya_vision, bamba, bark, bart, beit, bert, bert-generation, big_bird, bigbird_pegasus, biogpt, bit, bitnet, blenderbot, blenderbot-small, blip, blip-2, blip_2_qformer, bloom, blt, bridgetower, bros, camembert, canine, chameleon, chinese_clip, chinese_clip_vision_model, clap, clip, clip_text_model, clip_vision_model, clipseg, clvp, code_llama, codegen, cohere, cohere2, cohere2_vision, colpali, colqwen2, conditional_detr, convbert, convnext, convnextv2, cpmant, csm, ctrl, cvt, d_fine, dab-detr, dac, data2vec-audio, data2vec-text, data2vec-vision, dbrx, deberta, deberta-v2, decision_transformer, deepseek_v2, deepseek_v3, deepseek_vl, deepseek_vl_hybrid, deformable_detr, deit, depth_anything, depth_pro, deta, detr, dia, diffllama, dinat, dinov2, dinov2_with_registers, dinov3_convnext, dinov3_vit, distilbert, doge, donut-swin, dots1, dpr, dpt, edgetam, edgetam_video, edgetam_vision_model, efficientformer, efficientloftr, efficientnet, electra, emu3, encodec, encoder-decoder, eomt, ernie, ernie4_5, ernie4_5_moe, ernie_m, esm, evolla, exaone4, falcon, falcon_h1, falcon_mamba, fastspeech2_conformer, fastspeech2_conformer_with_hifigan, flaubert, flava, flex_olmo, florence2, fnet, focalnet, fsmt, funnel, fuyu, gemma, gemma2, gemma3, gemma3_text, gemma3n, gemma3n_audio, gemma3n_text, gemma3n_vision, git, glm, glm4, glm4_moe, glm4v, glm4v_moe, glm4v_moe_text, glm4v_text, glpn, got_ocr2, gpt-sw3, gpt2, gpt_bigcode, gpt_neo, gpt_neox, gpt_neox_japanese, gpt_oss, gptj, gptsan-japanese, granite, granite_speech, granitemoe, granitemoehybrid, granitemoeshared, granitevision, graphormer, grounding-dino, groupvit, helium, hgnet_v2, hiera, hubert, hunyuan_v1_dense, hunyuan_v1_moe, ibert, idefics, idefics2, idefics3, idefics3_vision, ijepa, imagegpt, informer, instructblip, instructblipvideo, internvl, internvl_vision, jamba, janus, jetmoe, jukebox, kosmos-2, kosmos-2.5, kyutai_speech_to_text, layoutlm, layoutlmv2, layoutlmv3, led, levit, lfm2, lfm2_vl, lightglue, lilt, llama, llama4, llama4_text, llava, llava_next, llava_next_video, llava_onevision, longcat_flash, longformer, longt5, luke, lxmert, m2m_100, mamba, mamba2, marian, markuplm, mask2former, maskformer, maskformer-swin, mbart, mctct, mega, megatron-bert, metaclip_2, mgp-str, mimi, minimax, ministral, mistral, mistral3, mixtral, mlcd, mllama, mm-grounding-dino, mobilebert, mobilenet_v1, mobilenet_v2, mobilevit, mobilevitv2, modernbert, modernbert-decoder, moonshine, moshi, mpnet, mpt, mra, mt5, musicgen, musicgen_melody, mvp, nat, nemotron, nezha, nllb-moe, nougat, nystromformer, olmo, olmo2, olmo3, olmoe, omdet-turbo, oneformer, open-llama, openai-gpt, opt, ovis2, owlv2, owlvit, paligemma, parakeet_ctc, parakeet_encoder, patchtsmixer, patchtst, pegasus, pegasus_x, perceiver, perception_encoder, perception_lm, persimmon, phi, phi3, phi4_multimodal, phimoe, pix2struct, pixtral, plbart, poolformer, pop2piano, prompt_depth_anything, prophetnet, pvt, pvt_v2, qdqbert, qwen2, qwen2_5_omni, qwen2_5_vl, qwen2_5_vl_text, qwen2_audio, qwen2_audio_encoder, qwen2_moe, qwen2_vl, qwen2_vl_text, qwen3, qwen3_moe, qwen3_next, qwen3_omni_moe, qwen3_vl, qwen3_vl_moe, qwen3_vl_moe_text, qwen3_vl_text, rag, realm, recurrent_gemma, reformer, regnet, rembert, resnet, retribert, roberta, roberta-prelayernorm, roc_bert, roformer, rt_detr, rt_detr_resnet, rt_detr_v2, rwkv, sam, sam2, sam2_hiera_det_model, sam2_video, sam2_vision_model, sam_hq, sam_hq_vision_model, sam_vision_model, seamless_m4t, seamless_m4t_v2, seed_oss, segformer, seggpt, sew, sew-d, shieldgemma2, siglip, siglip2, siglip2_vision_model, siglip_vision_model, smoll ...
# {"timestamp": "2026-06-12T14:35:31.104744Z", "level": "info", "event": "Training subprocess started (pid=6561)"}
# {"timestamp": "2026-06-12T14:35:31.133568Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 795.87}
# {"timestamp": "2026-06-12T14:35:31.248297Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 3.61}
# {"timestamp": "2026-06-12T14:35:31.578938Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 191.81}
# {"timestamp": "2026-06-12T14:35:31.724244Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 137.42}
# {"timestamp": "2026-06-12T14:35:32.257442Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 6.0}
# {"timestamp": "2026-06-12T14:35:32.892453Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.89}
# {"timestamp": "2026-06-12T14:35:32.897691Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 3.45}
# {"timestamp": "2026-06-12T14:35:34.391870Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.42}
# {"timestamp": "2026-06-12T14:35:34.407414Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 5.83}
# {"timestamp": "2026-06-12T14:35:35.898889Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 5.42}
# {"timestamp": "2026-06-12T14:35:35.906587Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.7}
# {"timestamp": "2026-06-12T14:35:36.364121Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.44}
# {"timestamp": "2026-06-12T14:35:37.393473Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2